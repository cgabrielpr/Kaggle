# %% [markdown]
# ![609e6ed4b0ed9f001e1e52ad.gif](data:image/gif;base64,...)

# %% [markdown]
# # Cómo descargar datasets desde Kaggle para usarlos en Google Colaboratory:

# %%
# Instalar Kaggle
# !pip install -q kaggle

# %%
# Importar el token json generado en Kaggle>Account>API
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bb8b00a2-2bc9-4c15-a3ea-1d1179f840d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb8b00a2-2bc9-4c15-a3ea-1d1179f840d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Crear una carpeta llamada kaggle
! mkdir ~/.kaggle

# %%
# Copiar el archivo kaggle.json al folder previamente creado
! cp kaggle.json ~/.kaggle/

# %%
# Otorgar permisos al json
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Listar todos los datasets en kaggle 
! kaggle datasets list
# Out:
# ref                                                             title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meirnizri/covid19-dataset                                       COVID-19 Dataset                                   5MB  2022-11-13 15:47:17          10820        318  1.0
# michals22/coffee-dataset                                        Coffee dataset                                    24KB  2022-12-15 20:02:12           1793         52  1.0
# thedevastator/jobs-dataset-from-glassdoor                       Salary Prediction                                  3MB  2022-11-16 13:52:31           6773        150  1.0
# ...

# %%
# Para descargar los datasets:
# 1. Ir a la página principal del dataset que queremos descargar.
# 2. Hacemos click en el botón a la derecha de New Notebook, 
# lo cual desplegará un menú y en él seleccionaremos la opción Copy API Command.
# 3. Añadir ! al inicio para comenzar la descarga
! kaggle datasets download -d prasy46/credit-score-prediction
! kaggle datasets download -d meirnizri/covid19-dataset
! kaggle datasets download -d thedevastator/jobs-dataset-from-glassdoor
! kaggle datasets download -d ahmettalhabektas/argentina-car-prices
# Out:
# ...
#  38% 5.00M/13.1M [00:00<00:00, 44.3MB/s]
# 100% 13.1M/13.1M [00:00<00:00, 75.7MB/s]
# ...
#   0% 0.00/4.66M [00:00<?, ?B/s]
# 100% 4.66M/4.66M [00:00<00:00, 196MB/s]
# ...
#   0% 0.00/3.23M [00:00<?, ?B/s]
# 100% 3.23M/3.23M [00:00<00:00, 154MB/s]
# ...
#   0% 0.00/7.64k [00:00<?, ?B/s]
# 100% 7.64k/7.64k [00:00<00:00, 7.14MB/s]

# %%
#Los archivos los encuentras directamente en 'Archivos' en la parte izquierda <---

# %%
#En caso de descargar archivos ZIP, utilizar !unzip <file.zip>
# !unzip credit-score-prediction.zip
# Out:
# Archive:  credit-score-prediction.zip
#   inflating: CreditScore_test.csv
#   inflating: CreditScore_train.csv

# %% [markdown]
# ## Importamos pandas para leer los archivos

# %%
import pandas as pd

# %%
data_test = pd.read_csv('/content/CreditScore_test.csv')
data_train = pd.read_csv('/content/CreditScore_train.csv')

# %%
data_train.info()
data_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Columns: 305 entries, x001 to y
# dtypes: float64(41), int64(264)
# memory usage: 186.2 MB
#       x001   x002  x003   x004   x005  x006  x007  x008  x009  x010  ...  \
# 0  1084094  426.0  39.0  128.0  426.0     0     0     0     0     0  ...
# 1  1287777  160.0   2.0   64.0  160.0     1     1     2     0     1  ...
# 2  1483016  163.0  16.0  104.0  239.0     0     0     0     1     0  ...
# 3   959054    NaN   NaN    NaN  102.0     0     0     0     0     0  ...
# 4  1342113    3.0   2.0    2.0   62.0     0     2     2     0     0  ...
#
#     x296    x297  x298  x299  x300  x301  x302  x303  x304    y
# 0      0     NaN     0     0     0     0   NaN     0   NaN  807
# 1  17318  0.8417     1     1     1     0   NaN     0   NaN  819
# 2      0     NaN     0     0     0     0   NaN     0   NaN  803
# 3      0     NaN     1     1     1     0   NaN     0   NaN  530
# ...

# %%
data_test.info()
data_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Columns: 305 entries, x001 to y
# dtypes: float64(41), int64(264)
# memory usage: 46.5 MB
#       x001   x002  x003   x004   x005  x006  x007  x008  x009  x010  ...  \
# 0  1566464   21.0  21.0   21.0   44.0     1     0     0     4     0  ...
# 1   925102  108.0   2.0   27.0  156.0     0     2     3     3     1  ...
# 2  1273974  218.0  64.0  107.0  218.0     0     0     0     0     0  ...
# 3  1456723    NaN   NaN    NaN  146.0     1     0     0     1     1  ...
# 4   798267    0.0   0.0    0.0  230.0     1     2     4     0     2  ...
#
#     x296   x297  x298  x299  x300  x301  x302   x303   x304    y
# 0      0    NaN     0     0     1     1   5.0      0    NaN  406
# 1  13090  0.593     1     1     1     0   1.0      0    NaN  679
# 2  13689  1.014     1     1     1     0   1.0  13689  1.014  750
# 3      0    NaN     1     1     1     0   NaN      0    NaN  515
# ...

# %% [markdown]
# ### Argetina Car Prices - Dataset

# %%
# !unzip argentina-car-prices.zip
# Out:
# Archive:  argentina-car-prices.zip
#   inflating: argentina_cars.csv

# %%
data_cars = pd.read_csv('argentina_cars.csv')

# %%
data_cars.info()
data_cars.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   money       510 non-null    int64
#  1   brand       510 non-null    object
#  2   model       510 non-null    object
#  3   year        510 non-null    int64
#  4   color       499 non-null    object
#  5   fuel_type   510 non-null    object
#  6   door        510 non-null    float64
#  7   gear        509 non-null    object
#  8   motor       499 non-null    object
#  9   body_type   509 non-null    object
#  10  kilometres  510 non-null    int64
#  11  currency    510 non-null    object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 47.9+ KB
#       money    brand          model  year        color fuel_type  door  \
# 0  10350000   Toyota  Corolla Cross  2022     Plateado     Nafta   5.0
# 1  10850000     Jeep        Compass  2022       Blanco     Nafta   5.0
# ...

# %% [markdown]
# ### Covid 19 - Dataset

# %%
# !unzip covid19-dataset.zip
# Out:
# Archive:  covid19-dataset.zip
#   inflating: Covid Data.csv

# %%
data_covid = pd.read_csv('/content/Covid Data.csv')

# %%
data_covid.info()
data_covid.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %% [markdown]
# ### Jobs from Glassdoor - Dataset

# %%
# !unzip jobs-dataset-from-glassdoor.zip
# Out:
# Archive:  jobs-dataset-from-glassdoor.zip
#   inflating: eda_data.csv
#   inflating: glassdoor_jobs.csv
#   inflating: salary_data_cleaned.csv

# %%
data_glassdoor = pd.read_csv('/content/glassdoor_jobs.csv')

# %%
data_glassdoor.info()
data_glassdoor.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...
